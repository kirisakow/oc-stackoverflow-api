# %% [markdown]
# # Test Requests
#
# Des requêtes de test

# %%
import json
import requests

url = 'http://localhost:5555/predict'
data = {'foo': 10}
response = requests.post(url, json=data) # or: (..., data=json.dumps(data))
print(response.json())
# Out:
# {'foo': 100}
