# %% [markdown]
# # Test Requests
#
# Des requêtes de test

# %%
import aiohttp
import asyncio
import ast
import pandas as pd


def truncated(string, n_chars, ending='...'):
    return string[:n_chars] + ending if len(string) >= n_chars + len(ending) else string


url = 'http://localhost:5555/predict'
df_questions = pd.read_csv('data/so.2024.12.csv', converters={'tags': ast.literal_eval})
question_body, expected_tags = df_questions.sample(1, axis=0, ignore_index=True).loc[0, ['body', 'tags']].values

async with aiohttp.ClientSession() as client:
    response = await client.post(url, data=question_body)
    predicted_tags = await response.json()

pd.options.display.max_colwidth = None
display(
    pd.DataFrame({
        'Expected tags:': str(sorted(expected_tags)),
        'Predicted tags:': str(sorted(predicted_tags)),
        'Input (title + body, truncated):': truncated(question_body, 300),
    }, index=[0])
)
# Out:
#   Expected tags:                                       ... Input (title + body, truncated):
# 0  ['android', 'android-auto', 'android-permissions']  ...  "SecurityException: Permission Denial: starting Intent" in Android Auto When I request permissions in Android Auto via theCarContextaccording to the docs, the app crashes whenLocal device is Android 15 (API Level 35, VanillaIceCream)Remote device is a car projection unitApp is started on remote unit...
#
# [1 rows x 3 columns]
